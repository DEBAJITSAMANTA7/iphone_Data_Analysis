# %% [markdown]
# My 1st Data Analysis Project

# %%
import pandas as pd

# %%
# data frame
# CSV file type means it seperated by , Comma 
#  In Python, backslashes (\) in strings can be interpreted as escape characters, so you should either:

# Use double backslashes \\ in your file path:
# OR /instead of \
# df=pd.read_csv("C:/Users/debaj/OneDrive/Desktop/DataEngineeringNew/apple_products.csv")
df=pd.read_csv("C:/Users/debaj/OneDrive/Desktop/DataEngineeringNew/iphone_Data_Analysis/apple_products.csv")
df.head()
# df.tail()
# Out:
#                                Product Name  \
# 0         APPLE iPhone 8 Plus (Gold, 64 GB)
# 1  APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2      APPLE iPhone 8 Plus (Silver, 256 GB)
# 3           APPLE iPhone 8 (Silver, 256 GB)
# 4             APPLE iPhone 8 (Gold, 256 GB)
#
#                                          Product URL  Brand  Sale Price  \
# 0  https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3  https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# 4  https://www.flipkart.com/apple-iphone-8-gold-2...  Apple       77000
#
#      Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 0  49900                    0               3431                356
# 1  84900                    0               3431                356
# ...

# %% [markdown]
# df.count()

# %%
df.count()
# df.count() in pandas, it returns the number of non-null (non-NaN) values in each column of the DataFrame.
# Out:
# Product Name           62
# Product URL            62
# Brand                  62
# Sale Price             62
# Mrp                    62
# Discount Percentage    62
# Number Of Ratings      62
# Number Of Reviews      62
# Upc                    62
# Star Rating            62
# Ram                    62
# dtype: int64

# %%
# df['Mrp'].max()
df['Mrp'].min()
# Using this we can identify that particular column highest &
#Lowest value
# Out:
# np.int64(39900)

# %%
# from now whch iphone is the min and min
df[df['Mrp']==df['Mrp'].max()]
# Out:
#                                   Product Name  \
# 24        APPLE iPhone 12 Pro (Silver, 512 GB)
# 41  APPLE iPhone 12 Pro (Pacific Blue, 512 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 24  https://www.flipkart.com/apple-iphone-12-pro-s...  Apple      140900
# 41  https://www.flipkart.com/apple-iphone-12-pro-p...  Apple      140900
#
#        Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 24  149900                    6                542                 42
# 41  149900                    6                545                 42
#
#                  Upc  Star Rating   Ram
# 24  MOBFWBYZ5UY6ZBVA          4.5  4 GB
# 41  MOBFWBYZTHSXKMGW          4.5  4 GB

# %%
# Show me the product that is min of the Mrp Table 
df[df['Mrp']==df['Mrp'].min()]
# Out:
#                       Product Name  \
# 52  APPLE iPhone SE (White, 64 GB)
# 57  APPLE iPhone SE (Black, 64 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 52  https://www.flipkart.com/apple-iphone-se-white...  Apple       29999
# 57  https://www.flipkart.com/apple-iphone-se-black...  Apple       29999
#
#       Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 52  39900                   24              95807               8154
# 57  39900                   24              95909               8161
#
#                  Upc  Star Rating   Ram
# 52  MOBFWQ6BGWDVGF3E          4.5  2 GB
# 57  MOBFWQ6BR3MK7AUG          4.5  4 GB

# %%
# df[df['Mrp']>100000]

# %%
# df[df['Product Name']=='APPLE iPhone SE (White, 64 GB)']
# df['Product Name']
type(df['Product Name'])
# pandas.core.series.Series
# Out:
# pandas.core.series.Series

# %%
list(df['Product Name'])[4].upper()
# Li=list(df['Product Name'])
# Li[9]
# Out:
# 'APPLE IPHONE 8 (GOLD, 256 GB)'

# %%
# list(df['Product Name'])[7].upper()
# [0:5:] spliting of the data 
list(df['Product Name'])[7][0:5:].upper()
# Out:
# 'APPLE'

# %%
# create new attribute AND add the value of type of the model and phone name 
df['Model Name']=df['Product Name'].str[6:15]
# .str[5:15]  cause of i store the value in the attribues from 6 to 15 in string form 

# df['Model Name'].head()
df.head()
# Out:
#                                Product Name  \
# 0         APPLE iPhone 8 Plus (Gold, 64 GB)
# 1  APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2      APPLE iPhone 8 Plus (Silver, 256 GB)
# 3           APPLE iPhone 8 (Silver, 256 GB)
# 4             APPLE iPhone 8 (Gold, 256 GB)
#
#                                          Product URL  Brand  Sale Price  \
# 0  https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3  https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# 4  https://www.flipkart.com/apple-iphone-8-gold-2...  Apple       77000
#
#      Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 0  49900                    0               3431                356
# 1  84900                    0               3431                356
# ...

# %%
# sort by start rating 
# df.sort_values(by=['Star Rating'],ascending=False)
df.sort_values(by=['Star Rating','Sale Price'],ascending=False)
# Out:
#                                         Product Name  \
# 14            APPLE iPhone 11 Pro Max (Gold, 256 GB)
# 16  APPLE iPhone 11 Pro Max (Midnight Green, 256 GB)
# 15             APPLE iPhone 11 Pro Max (Gold, 64 GB)
# 17       APPLE iPhone 11 Pro Max (Space Grey, 64 GB)
# 20   APPLE iPhone 11 Pro Max (Midnight Green, 64 GB)
# ..                                               ...
# 53                   APPLE iPhone SE (Black, 128 GB)
# 54                   APPLE iPhone SE (White, 128 GB)
# 55                     APPLE iPhone SE (Red, 128 GB)
# 52                    APPLE iPhone SE (White, 64 GB)
# 57                    APPLE iPhone SE (Black, 64 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 14  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple      131900
# 16  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple      131900
# 15  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple      117100
# ...
